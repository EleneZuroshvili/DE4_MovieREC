# %% [markdown]
# # Short-Term Memory

# %%
from agents import Agent, Runner, SQLiteSession, trace
from setup import bedrock_tool

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant comparing how healthy different foods are.
    If you answer, give a list of how healthy the foods are with a score from 1 to 10. Order by: healtiest food comes first.

    Example:
    Q: Compare X and Y
    A: X is healtier as Y.
    1) X: 8/10 - Very healthy but high in fructose
    2) Y: 3/10 - High in sugar and fat
    """,
    model="litellm/bedrock/eu.amazon.nova-lite-v1:0",
)

# %% [markdown]
# ## No Memory

# %%
result = await Runner.run(nutrition_agent, "Which is healthier, bananas or lollipop?")
print(result.final_output)
# Out:
# A: Bananas are healthier than lollipops.
#
# 1) Bananas: 9/10 - High in essential nutrients like potassium, vitamin B6, vitamin C, and dietary fiber. They are also low in fat and provide a good source of energy.
# 2) Lollipops: 1/10 - High in sugar with negligible nutritional value. They provide empty calories and can contribute to tooth decay and weight gain.

# %%
result = await Runner.run(nutrition_agent, "Add apples to the comparison")
print(result.final_output)
# Out:
# OPENAI_API_KEY is not set, skipping trace export
# Sure, let's compare the healthiness of apples with a few other common foods. Here's a list ordered by how healthy they are, with a score out of 10:
#
# 1) **Apples: 9/10**
#    - **Pros:** High in fiber, antioxidants, vitamin C, and various phytonutrients. Low in calories.
#    - **Cons:** Contains natural sugars, so overconsumption could affect blood sugar levels.
#
# 2) **Blueberries: 8/10**
#    - **Pros:** Rich in antioxidants, vitamin C, and fiber. Low in calories.
#    - **Cons:** High in natural sugars, so moderation is key.
#
# 3) **Spinach: 8/10**
#    - **Pros:** High in vitamins A, C, and K, magnesium, iron, and antioxidants. Low in calories.
#    - **Cons:** Contains oxalates, which can interfere with calcium absorption for some people.
#
# 4) **Salmon: 8/10**
#    - **Pros:** High in omega-3 fatty acids, high-quality protein, vitamins D and B12.
#    - **Cons:** Higher in calories compared to fruits and vegetables, and potential contaminants like mercury depending on the source.
#
# 5) **Almonds: 7/10**
#    - **Pros:** High in healthy fats, fiber, protein, magnesium, and vitamin E.
#    - **Cons:** High in calories, so portion control is important.
#
# 6) **Sweet Potatoes: 7/10**
#    - **Pros:** High in vitamins A, C, and B6, fiber, and antioxidants. Low in calories.
#    - **Cons:** Higher in natural sugars compared to some other vegetables.
#
# 7) **Oats: 7/10**
#    - **Pros:** High in fiber, particularly beta-glucan, which can help lower cholesterol. Good source of vitamins and minerals.
#    - **Cons:** Can be processed into less healthy products (e.g., instant oatmeal with added sugars).
#
# 8) **Yogurt (plain, unsweetened): 6/10**
#    - **Pros:** High in protein, probiotics, calcium, and vitamin B12.
#    - **Cons:** Some varieties contain added sugars and can be high in sodium.
#
# 9) **Whole Wheat Bread: 5/10**
#    - **Pros:** Higher in fiber and nutrients compared to white bread, contains some B vitamins and minerals.
#    - **Cons:** Still contains carbohydrates that can affect blood sugar levels, and may not be as nutrient-dense as whole foods like fruits and vegetables.
#
# 10) **Chocolate (dark, 70% cocoa or higher): 5/10**
#     - **Pros:** Contains antioxidants, flavonoids, and can improve heart health in moderation.
#     - **Cons:** High in calories and sugar, and can contain additives and fats.
#
# Apples are among the healthiest foods due to their rich nutrient profile and low calorie count, making them a top choice for regular consumption.

# %% [markdown]
# ## Short Term Memory

# %%
session = SQLiteSession("conversation_history")

# %%
result = await Runner.run(
    nutrition_agent, "Which is healthier, bananas or lollipop?", session=session
)
print(result.final_output)
# Out:
# A: Bananas are healthier than a lollipop.
#
# 1) Bananas: 9/10 - Rich in essential nutrients like potassium, vitamin B6, vitamin C, fiber, and antioxidants. They provide energy and support heart health, digestion, and muscle function.
#
# 2) Lollipop: 1/10 - High in sugar with little to no nutritional value. Consuming lollipops can contribute to weight gain, tooth decay, and increased risk of chronic diseases.

# %%
with trace("Simple Nutrition Agent"):
    result = await Runner.run(
        nutrition_agent, "Add apples to the comparison", session=session
    )

print(result.final_output)
# Out:
# A: Bananas are healthier than lollipops, and apples are also healthier than lollipops, but slightly less so than bananas.
#
# 1) Bananas: 9/10 - Rich in essential nutrients like potassium, vitamin B6, vitamin C, fiber, and antioxidants. They provide energy and support heart health, digestion, and muscle function.
#
# 2) Apples: 8/10 - High in fiber, vitamin C, and various antioxidants. They support heart health, digestive health, and provide a good source of energy.
#
# 3) Lollipop: 1/10 - High in sugar with little to no nutritional value. Consuming lollipops can contribute to weight gain, tooth decay, and increased risk of chronic diseases.
